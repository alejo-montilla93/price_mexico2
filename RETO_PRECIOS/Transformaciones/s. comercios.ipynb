# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import numpy as np
from sklearn.metrics.pairwise import haversine_distances
from math import radians

# %%
pref = 'comercio'

# %%
df1 = pd.read_csv('reto_precios.csv')
df2 = pd.read_csv('comercios.csv', encoding='latin-1')
# Out:
# C:\Users\alber\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df2.head()
# Out:
#         id                          clee  \
# 0  7702819  01001434225001101000000000S1
# 1  6282298  01005431110000031001004190S9
# 2  6281199  01001431191000106000002859S8
# 3  6281969  01001431110000121001004190S7
# 4  9312752  01001431110000753000000000U7
#
#                                   nom_estab                  raz_social  \
# 0      2 CONEXION DE SERVICIOS INFORMATICOS                         NaN
# 1  2227 ORGANIZACIÓN SAHUAYO AGUASCALIENTES  IMPULSORA SAHUAYO SA DE CV
# 2                            2252 AGUAS SUR              BIMBO SA DE CV
# 3                       2273 AGUASCALIENTES  IMPULSORA SAHUAYO SA DE CV
# 4                         5 W  DISTRIBUIDOR     5 W  TRADE LAB SA DE CV
#
#    codigo_act                                         nombre_act  \
# 0      434225  Comercio al por mayor de equipo y material elé...
# 1      431110                 Comercio al por mayor de abarrotes
# 2      431191            Comercio al por mayor de pan y pasteles
# 3      431110                 Comercio al por mayor de abarrotes
# 4      431110                 Comercio al por mayor de abarrotes
#
#               per_ocu  tipo_vial                    nom_vial tipo_v_e_1  \
# 0      0 a 5 personas      CALLE                   5 DE MAYO      CALLE
# 1  101 a 250 personas   CIRCUITO          AGUASCALIENTES SUR   CIRCUITO
# 2  101 a 250 personas  CARRETERA            PANAMERICANA SUR      CALLE
# 3  101 a 250 personas      CALLE                        SOYA    AVENIDA
# 4    11 a 30 personas      CALLE  ALFONSO BERNAL SANTOS C-6N    AVENIDA
#
#                          nom_v_e_1 tipo_v_e_2               nom_v_e_2  \
# 0               RIVERO Y GUTIERREZ   PEATONAL         ALLENDE ORIENTE
# 1  CIRCUITO AGUASCALIENTES ORIENTE      CALLE   MUNICIPIO DE CALVILLO
# 2              JESUS RIVERA FRANCO      CALLE  ANTONIO GUTIERREZ SOLA
# 3                    INDEPENDENCIA      CALLE                CEREALES
# 4                        SIGLO XXI      CALLE     JESUS RIVERA FRANCO
#
#   tipo_v_e_3                      nom_v_e_3  numero_ext letra_ext  \
# 0   PEATONAL                  BENITO JUÁREZ       219.0       NaN
# 1   CIRCUITO  CIRCUITO AGUASCALIENTES NORTE       126.0       NaN
# 2      CALLE       ANGEL DORRONSORO GANDARA         0.0        SN
# 3  BOULEVARD          BOULEVARD A ZACATECAS         1.0       NaN
# 4      CALLE     FILEMÓN ALONSO MUÑOZ C-10N       116.0       NaN
#
#                    edificio   edificio_e  numero_int letra_int  \
# 0  CENTRO Y PLAZA COMERCIAL  PLANTA BAJA       169.0       NaN
# 1                       NaN          NaN         0.0       NaN
# 2                       NaN          NaN         NaN       NaN
# 3                       NaN          NaN         NaN       NaN
# 4                       NaN          NaN         0.0       NaN
#
#           tipo_asent                                 nomb_asent  \
# 0            COLONIA                                ZONA CENTRO
# 1  PARQUE INDUSTRIAL  PARQUE INDUSTRIAL VALLE DE AGUASCALIENTES
# 2    FRACCIONAMIENTO                               LOS ARELLANO
# 3            COLONIA                               AGROPECUARIO
# 4    FRACCIONAMIENTO                          CIUDAD INDUSTRIAL
#
#                  tipoCenCom                                     nom_CenCom  \
# 0  CENTRO Y PLAZA COMERCIAL                         PLAZA DE LA TECNOLOGIA
# 1         PARQUE INDUSTRIAL  PARQUE INDUSTRIAL DEL VALLE DE AGUASCALIENTES
# 2         CIUDAD INDUSTRIAL                              CIUDAD INDUSTRIAL
# 3         CENTRAL DE ABASTO                  CENTRO COMERCIAL AGROPECUARIO
# 4                       NaN                                            NaN
#
#   num_local  cod_postal  cve_ent         entidad  cve_mun       municipio  \
# 0       169     20000.0        1  AGUASCALIENTES        1  Aguascalientes
# 1       126     20335.0        1  AGUASCALIENTES        5     Jesús María
# 2       115     20290.0        1  AGUASCALIENTES        1  Aguascalientes
# 3         1     20135.0        1  AGUASCALIENTES        1  Aguascalientes
# 4       NaN     20290.0        1  AGUASCALIENTES        1  Aguascalientes
#
#    cve_loc                                          localidad  ageb  manzana  \
# 0        1                                     Aguascalientes  0638       14
# 1      507  Parque Industrial del Valle de Aguascalientes ...  0035        3
# 2        1                                     Aguascalientes  1477       25
# 3        1                                     Aguascalientes  1975       16
# 4        1                                     Aguascalientes  1477       30
#
#     telefono                correoelec                 www tipoUniEco  \
# 0        NaN  SERVICIOS@2CONEXION..COM   WWW.2CONEXION.COM       Fijo
# 1        NaN                       NaN  WWW.SAHUAYO.COM.MX       Fijo
# 2        NaN                       NaN    WWW.BIMBO.COM.MX       Fijo
# 3        NaN                       NaN  WWW.SAHUAYO.COM.MX       Fijo
# 4  558079137                       NaN                 NaN       Fijo
#
#      latitud    longitud fecha_alta
# 0  21.882623 -102.297289    2019-11
# 1  21.963603 -102.279136    2010-07
# 2  21.840966 -102.280381    2010-07
# 3  21.910507 -102.296908    2010-07
# 4  21.842518 -102.288225    2020-11

# %%
df2.columns
# Out:
# Index(['id', 'clee', 'nom_estab', 'raz_social', 'codigo_act', 'nombre_act',
#        'per_ocu', 'tipo_vial', 'nom_vial', 'tipo_v_e_1', 'nom_v_e_1',
#        'tipo_v_e_2', 'nom_v_e_2', 'tipo_v_e_3', 'nom_v_e_3', 'numero_ext',
#        'letra_ext', 'edificio', 'edificio_e', 'numero_int', 'letra_int',
#        'tipo_asent', 'nomb_asent', 'tipoCenCom', 'nom_CenCom', 'num_local',
#        'cod_postal', 'cve_ent', 'entidad', 'cve_mun', 'municipio', 'cve_loc',
#        'localidad', 'ageb', 'manzana', 'telefono', 'correoelec', 'www',
#        'tipoUniEco', 'latitud', 'longitud', 'fecha_alta'],
#       dtype='object')

# %%
df1 = df1[['id','lat','lon']]
# Cambiar los nombres de las variables en df1 agregando sufijo 1
df1 = df1.rename(columns={ 'lat': 'lat1', 'lon': 'lon1'})
# Cambiar los nombres de las variables en df2 agregando sufijo 2
df2 = df2.rename(columns={'id': 'id2', 'latitud': 'lat2', 'longitud': 'lon2'})

# %%
# Definir la tolerancia espacial (en kilómetros)
tolerancia = 0.5

# Convertir las latitudes y longitudes a radianes
df1['lat_rad1'] = df1['lat1'].apply(radians)
df1['lon_rad1'] = df1['lon1'].apply(radians)
df2['lat_rad2'] = df2['lat2'].apply(radians)
df2['lon_rad2'] = df2['lon2'].apply(radians)

# %%
# Calcular la distancia haversine entre las coordenadas
distances = haversine_distances(df1[['lat_rad1', 'lon_rad1']], df2[['lat_rad2', 'lon_rad2']]) * 6371000/1000  # Convertir a kilómetros

# Encontrar las coincidencias dentro de la tolerancia
matches = distances <= tolerancia

# %%
matching_indices = np.where(matches)

# Crear una lista para almacenar los DataFrames combinados
combined_dfs = []

# Iterar sobre los índices y columnas de coincidencias
for idx, col in zip(*matching_indices):
    # Obtener los registros coincidentes de df1 y df2
    matching_record_df1 = df1.loc[idx]
    matching_record_df2 = df2.loc[col]
    
    # Combinar los registros en un DataFrame
    combined_record = pd.concat([matching_record_df1, matching_record_df2])
    combined_dfs.append(combined_record)

# Concatenar todos los DataFrames combinados en uno solo
final_combined_df = pd.concat(combined_dfs, axis=1).T

# %%
final_combined_df.head(3)
# Out:
#     id       lat1       lon1  lat_rad1  lon_rad1      id2  \
# 0  1.0  19.421317 -99.164182  0.338966 -1.730741  1028541
# 1  1.0  19.421317 -99.164182  0.338966 -1.730741  6883782
# 2  1.0  19.421317 -99.164182  0.338966 -1.730741  7732613
#
#                            clee                                 nom_estab  \
# 0  09015461110005161000000000S3  ABARROTES VINOS Y LICORES LA ONZA DE ORO
# 1  09015311311000024011000000U4             ALCOHOLES Y MELAZAS DE MEXICO
# 2  09015434221000751000000000U5                                ARTESANIAS
#
#                                raz_social codigo_act  \
# 0                                     NaN     431110
# 1  ALCOHOLES Y MELAZAS DE MEXICO SA DE CV     431212
# 2                                     NaN     434221
#
#                                           nombre_act            per_ocu  \
# 0                 Comercio al por mayor de abarrotes     0 a 5 personas
# 1           Comercio al por mayor de vinos y licores  51 a 100 personas
# 2  Comercio al por mayor de materiales metálicos ...     0 a 5 personas
#
#   tipo_vial     nom_vial tipo_v_e_1               nom_v_e_1 tipo_v_e_2  \
# 0   AVENIDA  CHAPULTEPEC   EJE VIAL    3 PONIENTE (SEVILLA)      CALLE
# 1     CALLE      DURANGO      CALLE              VALLADOLID    AVENIDA
# 2     CALLE      LONDRES   EJE VIAL  2 PONIENTE (FLORENCIA)      CALLE
#
#             nom_v_e_2 tipo_v_e_3  nom_v_e_3 numero_ext letra_ext edificio  \
# 0               PRAGA      CALLE    LONDRES      425.0       NaN      NaN
# 1  PLAZA VILLA MADRID      CALLE    SINALOA      195.0       NaN      NaN
# 2             AMBERES      CALLE  LIVERPOOL      154.0       NaN      NaN
#
#   edificio_e numero_int letra_int tipo_asent nomb_asent tipoCenCom nom_CenCom  \
# 0        NaN        NaN       NaN    COLONIA     JUAREZ        NaN        NaN
# 1        NaN      202.0       NaN    COLONIA       ROMA        NaN        NaN
# 2        NaN        0.0       NaN    COLONIA     JUAREZ        NaN        NaN
#
#   num_local cod_postal cve_ent           entidad cve_mun   municipio cve_loc  \
# 0       NaN     6600.0       9  CIUDAD DE MÉXICO      15  Cuauhtémoc       1
# 1       NaN     6700.0       9  CIUDAD DE MÉXICO      15  Cuauhtémoc       1
# 2       NaN     6600.0       9  CIUDAD DE MÉXICO      15  Cuauhtémoc       1
#
#     localidad  ageb manzana telefono                 correoelec  \
# 0  Cuauhtémoc  0983       3      NaN                        NaN
# 1  Cuauhtémoc  0998       4      NaN  ALILLYMARTINEZ@ALIMEL.COM
# 2  Cuauhtémoc  095A       6      NaN                        NaN
#
#               www tipoUniEco       lat2       lon2 fecha_alta  lat_rad2  \
# 0             NaN       Fijo  19.422574  -99.16873    2010-07  0.338988
# 1  WWW.ALYMEL.COM       Fijo  19.419896   -99.1671    2019-04  0.338941
# 2             NaN       Fijo   19.42458 -99.165615    2019-11  0.339023
#
#    lon_rad2
# 0 -1.730821
# 1 -1.730792
# 2 -1.730766

# %%
len(final_combined_df)
# Out:
# 47801

# %%
final_combined_df['numero_ext'].value_counts()
# Out:
# 83.0      1152
# 245.0     1083
# 63.0       978
# 177.0      969
# 273.0      920
#           ...
# 405.0        1
# 1717.0       1
# 1445.0       1
# 1582.0       1
# 483.0        1
# Name: numero_ext, Length: 455, dtype: int64

# %%
final_combined_df['manzana'].value_counts()
# Out:
# 4     3691
# 14    3605
# 9     2901
# 2     2868
# 13    2863
# 6     2525
# 11    2441
# 7     2390
# 8     2282
# 19    2149
# 5     1975
# 3     1887
# 1     1845
# 20    1750
# 12    1452
# 10    1443
# 18    1416
# 24    1190
# 22    1169
# 15    1075
# 16    1025
# 23     999
# 17     990
# 21     825
# 25     351
# 27     220
# 28     195
# 26     118
# 46      62
# 29      35
# 35      14
# 44      12
# 32      10
# 31       9
# 30       5
# 49       5
# 40       5
# 48       1
# 55       1
# 42       1
# 34       1
# Name: manzana, dtype: int64

# %%
final_combined_df['per_ocu'].value_counts()
# Out:
# 0 a 5 personas        27195
# 11 a 30 personas       7915
# 6 a 10 personas        6957
# 31 a 50 personas       3144
# 51 a 100 personas      1803
# 101 a 250 personas      507
# 251 y más personas      280
# Name: per_ocu, dtype: int64

# %%
personal_ocupado = {'0 a 5 personas' : 1,
'6 a 10 personas' : 2,
'11 a 30 personas' : 3,
'31 a 50 personas' : 4,
'51 a 100 personas' : 5,
'101 a 250 personas' : 6,
'251 y más personas' : 7}

final_combined_df['per_ocu'] = final_combined_df['per_ocu'].replace(personal_ocupado)
final_combined_df['per_ocu'].value_counts()
# Out:
# 1    27195
# 3     7915
# 2     6957
# 4     3144
# 5     1803
# 6      507
# 7      280
# Name: per_ocu, dtype: int64

# %%
#per_ocu
#numero_ext
#manzana

# %%
final_combined_df['dif_lat_rad'] =final_combined_df['lat_rad1']-final_combined_df['lat_rad2']
final_combined_df['dif_lon_rad'] =final_combined_df['lon_rad1']-final_combined_df['lon_rad2']

# %%
(final_combined_df['lat_rad1']-final_combined_df['lat_rad2'])
# Out:
# 0       -0.000022
# 1        0.000025
# 2       -0.000057
# 3       -0.000022
# 4       -0.000035
#            ...
# 47796   -0.000039
# 47797    0.000004
# 47798    0.000059
# 47799   -0.000051
# 47800   -0.000007
# Length: 47801, dtype: object

# %%
final_combined_df.entidad.value_counts()
# Out:
# CIUDAD DE MÉXICO    47383
# NUEVO LEÓN            415
# BAJA CALIFORNIA         3
# Name: entidad, dtype: int64

# %%
final_combined_df[final_combined_df.entidad.str.contains('NUEVO LEÓN')][['id','dif_lat_rad','dif_lon_rad']]
# Out:
#           id dif_lat_rad dif_lon_rad
# 2448    54.0    0.000011    0.000039
# 2449    54.0   -0.000009     0.00003
# 2450    54.0    0.000047   -0.000013
# 2451    54.0   -0.000003    0.000026
# 2452    54.0   -0.000046    0.000053
# ...      ...         ...         ...
# 46240  952.0   -0.000067   -0.000021
# 46241  952.0   -0.000002   -0.000064
# 46242  952.0   -0.000023    0.000038
# 46243  952.0   -0.000013    -0.00005
# 46244  952.0   -0.000052    0.000059
#
# [415 rows x 3 columns]

# %%
final_combined_df[final_combined_df.entidad.str.contains('BAJA CALIFORNIA')][['id','dif_lat_rad','dif_lon_rad']]
# Out:
#           id dif_lat_rad dif_lon_rad
# 28885  583.0    0.000005   -0.000044
# 28886  583.0    0.000009   -0.000057
# 28887  583.0   -0.000055     0.00001

# %%
summary = final_combined_df[['id','per_ocu','numero_ext','manzana']]
summary.head()
# Out:
#     id  per_ocu numero_ext manzana
# 0  1.0        1      425.0       3
# 1  1.0        5      195.0       4
# 2  1.0        1      154.0       6
# 3  1.0        1      151.0       8
# 4  1.0        1       53.0       6

# %%
# Definir las columnas para la agrupación y agregación
aggregation_columns = ['per_ocu', 'numero_ext', 'manzana']  # Agrega aquí las columnas que quieras sumar

# Realizar la agrupación y las agregaciones
grouped_df = summary.groupby('id')[aggregation_columns].agg({'sum'}).reset_index()
grouped_df2 = summary.groupby('id').agg(total=('id', 'count')).reset_index()
grouped_df2.columns = ['id'] + [f'{pref}_total']



# Renombrar las columnas resultantes
grouped_df.columns = ['id'] + [f'{pref}_suma_{col}' for col in aggregation_columns]

# Mostrar el DataFrame resultante
centros = grouped_df2.merge(grouped_df)

# %%
centros.head()
# Out:
#     id  comercio_total  comercio_suma_per_ocu comercio_suma_numero_ext  \
# 0  1.0              61                    117                   9730.0
# 1  2.0              57                    111                   8170.0
# 2  3.0              42                     78                   5828.0
# 3  4.0              29                     60                   4879.0
# 4  5.0              47                     87                   4481.0
#
#   comercio_suma_manzana
# 0                   666
# 1                   636
# 2                   404
# 3                   253
# 4                   573

# %%
centros.to_csv('centros_'+pref+'s'+'.csv')
